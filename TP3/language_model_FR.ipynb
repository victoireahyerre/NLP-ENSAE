# %% [markdown]
# # NLP Lab : Modèles de langue
#
# Dans ce tp, nous allons constuire les briques principales du modèle GPT2 et entrainer un petit modèle sur des poèmes de Victor Hugo.
#
# Les questions sont posées dans ce notebook, puis pour executer l'entrainement, il faudra modifier le ficher `gpt_single_head.py` aussi disponible dans le reposository git.
#
#
# ## Données
#
# Les données d'entrainement sont un recueil de poèmes de Victor Hugo issu du site [gutenberg.org](https://www.gutenberg.org/). Elles sont disponibles dans le répertoire `data`.
#
# Afin de réduire la complexité du modèle, nous allons modéliser le texte au niveau caractère. Les modèles de language modélisent généralement des séquences de sous-mots en utilisant des [tokenizers](https://huggingface.co/docs/transformers/tokenizer_summary) (BPE, SentencePiece, WordPiece)
#
# Questions :
# >* En utilisant [collections.Counter](https://docs.python.org/3/library/collections.html#collections.Counter), afficher le nombre de caractères différents dans le texte et la fréquence de chaque caractère.

# %%
import collections

with open('data/hugo_contemplations.txt', 'r', encoding='utf-8') as f:
    text = f.read()

print(f'Number of characters in the file: {len(text)}')

##  YOUR CODE HERE
counter = collections.Counter(text)
chars = set(text)
###

print (f'Number of character in counter: {sum(counter.values())}')
print (f'{len(chars)} different characters')
print (counter)
# Out:
# Number of characters in the file: 285222
# Number of character in counter: 285222
# 101 different characters
# Counter({' ': 49127, 'e': 30253, 's': 17987, 'u': 14254, 'r': 14223, 't': 14071, 'a': 14048, 'n': 13725, 'i': 12828, 'o': 12653, 'l': 11638, '\n': 8102, 'm': 6495, 'd': 6375, ',': 6077, 'c': 5074, 'p': 4206, "'": 3820, 'v': 3492, 'é': 2943, 'b': 2783, 'f': 2772, 'h': 2221, 'q': 1956, 'g': 1790, '.': 1420, 'x': 1154, 'L': 1147, '!': 1121, 'E': 1074, ';': 1043, '-': 1020, 'j': 890, 'D': 764, 'è': 725, 'à': 706, 'y': 660, 'I': 627, 'ê': 605, 'C': 593, 'S': 545, 'A': 530, 'Q': 503, 'z': 482, 'J': 471, 'O': 450, 'T': 441, 'P': 435, '?': 388, 'V': 383, 'â': 381, 'N': 362, 'M': 344, 'ù': 298, ':': 294, 'R': 240, 'î': 214, 'U': 208, 'ô': 159, 'X': 150, '1': 146, 'H': 116, 'F': 114, '5': 111, '8': 93, 'B': 78, '«': 74, 'É': 70, '»': 69, 'G': 67, '4': 64, 'û': 62, '3': 47, 'ç': 34, 'À': 33, 'ë': 32, 'ï': 31, '2': 30, '·': 26, 'Ê': 24, '6': 23, '7': 23, 'Ô': 19, '9': 19, 'È': 11, 'k': 10, '0': 10, '_': 8, 'Z': 7, 'Æ': 4, '[': 4, ']': 4, 'w': 3, 'K': 3, 'Y': 3, 'Ë': 2, '(': 2, ')': 2, 'Â': 2, 'Î': 1, 'W': 1})

# %% [markdown]
# ### Encodage / décodage
# Afin de transformer le texte en vecteur pour le réseau de neurones, il faut encoder chaque caractère avec un entier. Les fonctions suivantes opérent l'encodage et le décodage des caractères :

# %%
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: transform a string into a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: transform a list of integers into a string


# test that your encoder/decoder is coherent
testString = "\nDemain, dès l'aube"
assert decode(encode (testString)) ==  testString

# %% [markdown]
# ### Découpage Train/Validation
#
# L'objectif étant de prédire des poèmes, il ne faut pas mélanger les lignes aléatoirement. Il faut garder l'ordre des lignes dans le texte et uniquement prendre les premiers 90% pour entrainer et les 10% restants pour contrôler l'apprentissage.
#
# Questions :
# > * Découper en `train_data` (90%) et `val_data` (10%) en utilisant du slicing sur data.

# %%
import torch
# Train and validation splits
data = torch.tensor(encode(text), dtype=torch.long)
## YOUR CODE HERE
# first 90% will be train, rest val
split = int(len(data)*0.9)
train_data, val_data = data[:split], data[split:]
###

# %% [markdown]
# ### Contexte
#
# Le modèle de langue possède comme paramètre la taille maximale du contexte à considérer pour faire la prédiction du prochain caractère. Ce contexte est appelé `block_size`. Les données d'apprentissage sont donc des séquences de caractères consécutifs, issues de l'ensemble d'entraînenement tirées aléatoirement et de longueur `block_size`.
#
# Si le caractère de début de la séquence est `i`, la séquence de contexte est donc :
# ``` x = data[i:i+block_size]```
# et la valeur à prédire à chaque position dans le contexte est le caractère suivant :
# ```y = [data[i+1:i+block_size+1]```.

# %%
block_size = 8

i  = torch.randint(len(data) - block_size, (1,))
print (i)
x = train_data[i:i+block_size]
y = train_data[i+1:i+1+block_size]

for t in range(block_size):
    context = x[:t+1]
    target = y[t]
    print (f'context is >{decode(context.tolist())}< target is >{decode([target.tolist()])}<')
# Out:
# tensor([23210])
# context is > < target is >c<
# context is > c< target is >e<
# context is > ce< target is >t<
# context is > cet< target is > <
# context is > cet < target is >a<
# context is > cet a< target is >z<
# context is > cet az< target is >u<
# context is > cet azu< target is >r<

# %% [markdown]
# ### Définition des batchs
#
# Les batchs d'entrainement sont constitués de plusieurs séquences de caractères tirées aléatoirement dans `train_data`. Pour choisir aléatoirement une séquence à mettre dans le batch, il faut tirer aléatoirement un point de départ dans `train_data` et extraire les `block_size` caractères suivants. Lors du tirage du point de départ, faire attention à laisser suffisamment de caractères après le point de départ pour avoir une séquence de `block_size` caractères.
#
# Questions :
# > * Créer les batchs `x` en tirant `batch_size` séquences de longeur `block_size` à  partir d'un point `i` tiré aléatoirement. Empiler les exemples avec `torch.stack`.
# > * Créer les batchs `y` en ajoutant le caractère suivant la séquence `x`. Empiler les exemples avec `torch.stack`.

# %%
batch_size = 4
torch.manual_seed(2023)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ## YOUR CODE HERE
    # select batch_size starting points in the data, store them in a list called starting_points
    starting_points = torch.randint(len(data) - block_size, (batch_size,))
    # x is the sequence of integer starting at each straing point and of length block_size
    x = torch.stack([data[i:i+block_size] for i in starting_points])
    # y is the character after each starting position
    y = torch.stack([data[i+1:i+1+block_size] for i in starting_points])
    ### 
    # send data and target to device
    x, y = x.to(device), y.to(device)
    return x, y

# %% [markdown]
# ### Premier modèle : un bigramme
#
# Le premier modèle que nous allons implémenter est un modèle bigramme. Il prédit le caractère suivant uniquement en fonction du caractère courant. Il est possible de stocker ce modèle dans une simple matrice : pour chaque caractère (en ligne), on stocke la distribution de probabilités sur l'ensemble des caractères suivants (en colonne). On peut donc le stocker dans une simple couche [`Embedding`](https://pytorch.org/docs/stable/generated/torch.nn.Embedding.html).
#
# Questions :
# > * Dans le constructeur, définir une couche Embedding de taille `vocab_size` par `vocab_size`.
# > * Dans forward, appliquer la couche d'embedding au batch de idx (`x`).
# > * Dans forward, définir la loss comme la `cross_entropy` entre la prédiction et target (`y`).

# %%
import torch.nn as nn

# use a gpu if we have one
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self, vocab_size):
        super().__init__()
        # we use a simple vocab_size times vocab_size tensor to store the probabilities 
        # of each token given a single token as context in nn.Embedding
        # YOUR CODE HERE
        self.embedding = nn.Embedding(vocab_size, vocab_size)
        ## 
        
    def forward(self, idx, targets=None):

        # idx and targets are both (Batch,Time) tensor of integers
        # YOUR CODE HERE
        logits = self.embedding(idx)
        ## 
   
        # don't compute loss if we don't have targets
        if targets is None:
            loss = None
        else:
            # change the shape of the logits and target to match what is needed for CrossEntropyLoss
            # https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html
            Batch, Time, Channels = logits.shape
            logits = logits.view(Batch*Time, Channels)
            targets = targets.view(Batch*Time)
            
            # negative log likelihood between prediction and target
            # YOUR CODE HERE
            loss = nn.functional.cross_entropy(logits, targets)
            ## 

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # get the predictions
            logits, loss = self(idx)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = nn.functional.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

vocab_size = len(chars) 
model = BigramLanguageModel(vocab_size)
# send the model to device
m = model.to(device)

# %% [markdown]
# #### Modèle avant entraînement
# Le modèle n'a pas encore été entrainé, il est juste initialisé, mais on peut calculer la loss sur un batch aléatoire. Les poids étant initialisés avec une distribution normale N(0,1) sur chaque dimension, la loss attendue après l'initialisation devrait être proche de `-ln(1/vocab_size)` (l'entropie est maximale).

# %%
import math
xb, yb = get_batch('train')
logits, loss = m(xb, yb)
print (logits.shape)
print (f'loss attendue {-math.log(1.0/vocab_size)}')
print (f'loss calculée {loss}')
# Out:
# torch.Size([32, 101])
# loss attendue 4.61512051684126
# loss calculée 5.238862037658691

# %% [markdown]
# Pour utiliser le modèle en prédiction, il faut lui fournir un premier caractère pour amorcer la séquence : c'est le prompt. Dans notre cas, on peut initialiser la génération avec le caractère de retour à la ligne pour débuter une nouvelle phrase.
#
# Questions :
# > * Créer un prompt avec un tenseur de taille (1,1) contenant l'entier correspondant au caractère `\n`.
# > * Générer une séquence de caractères de taille 100 à partir de ce prompt avec les fonctions `m.generate` et `decode`.
# > * Comment est la phrase générée ?

# %%
print (encode(['\n']))
## YOUR CODE HERE
prompt = torch.tensor(encode(['\n']), dtype=torch.long).unsqueeze(0).to(device)
print(prompt)
generated = decode(m.generate(prompt, 100)[0].tolist())
print(generated)
###
# Out:
# [67]
# tensor([[67]])
#
# CvyÀ8LEXûà(OWEÆà]OU_5A8g ZE'n6ùtB6»kRPxÎ-Pryopà02_pgKÆQ;Vs«ç_
# OzSzm0qaVÂÈ1hÉkÉuGÀuB4nh[ïJqHimIvï)x6û

# %% [markdown]
# La phrase générée ne ressemble à rien.

# %% [markdown]
# ### Entrainement
#
# Pour l'entrainement, nous utilisons un optimiseur [AdamW](https://pytorch.org/docs/stable/generated/torch.optim.AdamW.html) avec un learning rate de 1e-3. Une itération d'apprentissage consiste en
# - générer un batch
# - appliquer le réseau de neurones (forward) et calculer la loss (`model(xb, yb)`)
# - calculer le gradient (après avoir remis à zero le gradient cumulé) (`loss.backward()`)
# - mettre à jour les paramètres (`optimizer.step()`).

# %%
max_iters = 10000
batch_size = 4
eval_interval = 10
learning_rate = 1e-3
eval_iters = 20

@torch.no_grad() # no gradient is computed here
def estimate_loss():
    """ Estimate the loss on eval_iters batch of train and val sets."""
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# re-create the model
model = BigramLanguageModel(vocab_size)
m = model.to(device)

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = m(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# Out:
# step 0: train loss 5.0090, val loss 5.0079
# step 10: train loss 4.9967, val loss 5.0236
# step 20: train loss 5.0156, val loss 5.0121
# step 30: train loss 5.0563, val loss 5.0465
# step 40: train loss 4.9601, val loss 4.9886
# step 50: train loss 4.9282, val loss 4.9126
# step 60: train loss 5.0194, val loss 4.9511
# step 70: train loss 4.9459, val loss 4.9401
# step 80: train loss 4.9548, val loss 4.8937
# step 90: train loss 4.9511, val loss 4.8943
# step 100: train loss 4.9360, val loss 4.9320
# step 110: train loss 4.9020, val loss 4.8924
# step 120: train loss 4.9144, val loss 4.8995
# step 130: train loss 4.9318, val loss 4.9069
# step 140: train loss 4.9142, val loss 4.9408
# step 150: train loss 4.8795, val loss 4.8952
# step 160: train loss 4.8739, val loss 4.8690
# step 170: train loss 4.7810, val loss 4.7984
# step 180: train loss 4.8653, val loss 4.8267
# step 190: train loss 4.8626, val loss 4.9057
# step 200: train loss 4.7778, val loss 4.8753
# step 210: train loss 4.8704, val loss 4.8877
# step 220: train loss 4.7846, val loss 4.8475
# step 230: train loss 4.7507, val loss 4.7647
# step 240: train loss 4.8686, val loss 4.7859
# step 250: train loss 4.8129, val loss 4.7408
# step 260: train loss 4.7806, val loss 4.7421
# step 270: train loss 4.8123, val loss 4.8029
# step 280: train loss 4.7037, val loss 4.8007
# step 290: train loss 4.7044, val loss 4.7597
# step 300: train loss 4.7548, val loss 4.7886
# step 310: train loss 4.7535, val loss 4.7296
# step 320: train loss 4.6938, val loss 4.8195
# step 330: train loss 4.6991, val loss 4.7899
# step 340: train loss 4.6539, val loss 4.7461
# step 350: train loss 4.6991, val loss 4.7141
# step 360: train loss 4.6952, val loss 4.7473
# step 370: train loss 4.7216, val loss 4.6510
# step 380: train loss 4.6685, val loss 4.6415
# step 390: train loss 4.6665, val loss 4.6671
# step 400: train loss 4.7174, val loss 4.6312
# step 410: train loss 4.6755, val loss 4.6770
# step 420: train loss 4.6947, val loss 4.6450
# step 430: train loss 4.6476, val loss 4.6753
# step 440: train loss 4.6339, val loss 4.5881
# step 450: train loss 4.6398, val loss 4.6165
# step 460: train loss 4.6125, val loss 4.6661
# step 470: train loss 4.5640, val loss 4.6143
# step 480: train loss 4.5344, val loss 4.5411
# step 490: train loss 4.6112, val loss 4.5947
# step 500: train loss 4.5734, val loss 4.5344
# step 510: train loss 4.6476, val loss 4.5767
# step 520: train loss 4.5700, val loss 4.5925
# step 530: train loss 4.5097, val loss 4.5361
# step 540: train loss 4.5585, val loss 4.4644
# step 550: train loss 4.5518, val loss 4.5519
# step 560: train loss 4.5679, val loss 4.5993
# step 570: train loss 4.5370, val loss 4.5829
# step 580: train loss 4.5551, val loss 4.5410
# step 590: train loss 4.5130, val loss 4.5483
# step 600: train loss 4.5737, val loss 4.5457
# step 610: train loss 4.5259, val loss 4.6073
# step 620: train loss 4.5132, val loss 4.4813
# step 630: train loss 4.4546, val loss 4.5813
# step 640: train loss 4.5459, val loss 4.4582
# step 650: train loss 4.4776, val loss 4.5076
# step 660: train loss 4.4126, val loss 4.4815
# step 670: train loss 4.3856, val loss 4.4287
# step 680: train loss 4.4230, val loss 4.4944
# step 690: train loss 4.4526, val loss 4.5047
# step 700: train loss 4.3644, val loss 4.4368
# step 710: train loss 4.3244, val loss 4.4608
# step 720: train loss 4.3907, val loss 4.4459
# step 730: train loss 4.4544, val loss 4.3764
# step 740: train loss 4.3538, val loss 4.4311
# step 750: train loss 4.3928, val loss 4.3465
# step 760: train loss 4.4172, val loss 4.3480
# step 770: train loss 4.3969, val loss 4.4306
# step 780: train loss 4.3935, val loss 4.3473
# step 790: train loss 4.3525, val loss 4.4496
# step 800: train loss 4.2989, val loss 4.4113
# step 810: train loss 4.4160, val loss 4.3522
# step 820: train loss 4.3948, val loss 4.3831
# step 830: train loss 4.3196, val loss 4.3958
# step 840: train loss 4.2859, val loss 4.4157
# step 850: train loss 4.4047, val loss 4.3816
# step 860: train loss 4.3280, val loss 4.3680
# step 870: train loss 4.3487, val loss 4.3015
# step 880: train loss 4.2620, val loss 4.3808
# step 890: train loss 4.3218, val loss 4.3893
# step 900: train loss 4.2316, val loss 4.3354
# step 910: train loss 4.2498, val loss 4.2682
# step 920: train loss 4.2983, val loss 4.2934
# step 930: train loss 4.2331, val loss 4.2303
# step 940: train loss 4.2540, val loss 4.3342
# step 950: train loss 4.2381, val loss 4.3331
# step 960: train loss 4.2415, val loss 4.2967
# step 970: train loss 4.2904, val loss 4.3325
# step 980: train loss 4.2107, val loss 4.3000
# step 990: train loss 4.2057, val loss 4.1592
# step 1000: train loss 4.1420, val loss 4.2208
# step 1010: train loss 4.1801, val loss 4.2978
# step 1020: train loss 4.1908, val loss 4.2497
# step 1030: train loss 4.2045, val loss 4.1044
# step 1040: train loss 4.1612, val loss 4.1847
# step 1050: train loss 4.2038, val loss 4.1776
# step 1060: train loss 4.2164, val loss 4.1881
# step 1070: train loss 4.1514, val loss 4.2578
# step 1080: train loss 4.0891, val loss 4.1687
# step 1090: train loss 4.1466, val loss 4.2240
# step 1100: train loss 4.1738, val loss 4.1960
# step 1110: train loss 4.1297, val loss 4.1838
# step 1120: train loss 4.0685, val loss 4.1588
# step 1130: train loss 4.0911, val loss 4.1708
# step 1140: train loss 4.0644, val loss 4.2152
# step 1150: train loss 4.0840, val loss 4.1754
# step 1160: train loss 4.1450, val loss 4.1682
# step 1170: train loss 4.0697, val loss 4.1720
# step 1180: train loss 4.1186, val loss 4.1555
# step 1190: train loss 4.0170, val loss 4.1638
# step 1200: train loss 4.0528, val loss 4.1219
# step 1210: train loss 4.1120, val loss 4.0996
# step 1220: train loss 4.1174, val loss 4.1511
# step 1230: train loss 4.0614, val loss 4.1281
# step 1240: train loss 4.0380, val loss 4.1338
# step 1250: train loss 4.0278, val loss 4.0872
# step 1260: train loss 4.0227, val loss 4.0688
# step 1270: train loss 3.9974, val loss 4.0602
# step 1280: train loss 4.0252, val loss 4.1240
# step 1290: train loss 4.0483, val loss 4.0726
# step 1300: train loss 4.0307, val loss 4.0240
# step 1310: train loss 4.0286, val loss 4.0028
# step 1320: train loss 4.0461, val loss 4.0208
# step 1330: train loss 4.0035, val loss 3.9845
# step 1340: train loss 3.9903, val loss 4.0365
# step 1350: train loss 3.9817, val loss 4.1094
# step 1360: train loss 3.9416, val loss 4.0213
# step 1370: train loss 3.9850, val loss 4.0363
# step 1380: train loss 3.9646, val loss 4.0189
# step 1390: train loss 3.9151, val loss 3.9353
# step 1400: train loss 3.9427, val loss 4.0197
# step 1410: train loss 3.9225, val loss 3.9698
# step 1420: train loss 3.9586, val loss 4.0171
# step 1430: train loss 3.9324, val loss 3.9661
# step 1440: train loss 3.9188, val loss 3.9725
# step 1450: train loss 3.9571, val loss 3.9848
# step 1460: train loss 3.9273, val loss 4.0066
# step 1470: train loss 3.9304, val loss 3.9263
# step 1480: train loss 3.8512, val loss 3.9069
# step 1490: train loss 3.8835, val loss 3.9808
# step 1500: train loss 3.8830, val loss 3.9913
# step 1510: train loss 3.8264, val loss 3.9653
# step 1520: train loss 3.8901, val loss 3.8975
# step 1530: train loss 3.8257, val loss 3.9702
# step 1540: train loss 3.8776, val loss 3.8891
# step 1550: train loss 3.9167, val loss 3.8925
# step 1560: train loss 3.9372, val loss 3.9013
# step 1570: train loss 3.8676, val loss 3.9221
# step 1580: train loss 3.8544, val loss 3.8651
# step 1590: train loss 3.8634, val loss 3.9170
# step 1600: train loss 3.7800, val loss 3.8614
# step 1610: train loss 3.8976, val loss 3.8684
# step 1620: train loss 3.8313, val loss 3.8546
# step 1630: train loss 3.8314, val loss 3.8721
# step 1640: train loss 3.7841, val loss 3.8021
# step 1650: train loss 3.8577, val loss 3.9648
# step 1660: train loss 3.8086, val loss 3.8865
# step 1670: train loss 3.7771, val loss 3.8960
# step 1680: train loss 3.7978, val loss 3.8297
# step 1690: train loss 3.7457, val loss 3.8528
# step 1700: train loss 3.8548, val loss 3.8023
# step 1710: train loss 3.7591, val loss 3.8598
# step 1720: train loss 3.7491, val loss 3.8539
# step 1730: train loss 3.7507, val loss 3.8258
# step 1740: train loss 3.7940, val loss 3.8873
# step 1750: train loss 3.8304, val loss 3.8026
# step 1760: train loss 3.7101, val loss 3.8132
# step 1770: train loss 3.7320, val loss 3.7897
# step 1780: train loss 3.7192, val loss 3.7881
# step 1790: train loss 3.7321, val loss 3.8604
# step 1800: train loss 3.7054, val loss 3.7925
# step 1810: train loss 3.7727, val loss 3.8528
# step 1820: train loss 3.6695, val loss 3.8549
# step 1830: train loss 3.6810, val loss 3.8324
# step 1840: train loss 3.7154, val loss 3.7565
# step 1850: train loss 3.7461, val loss 3.7633
# step 1860: train loss 3.7427, val loss 3.7546
# step 1870: train loss 3.6970, val loss 3.8421
# step 1880: train loss 3.7472, val loss 3.7386
# step 1890: train loss 3.7069, val loss 3.8415
# step 1900: train loss 3.6799, val loss 3.7175
# step 1910: train loss 3.7450, val loss 3.7755
# step 1920: train loss 3.6450, val loss 3.7148
# step 1930: train loss 3.7020, val loss 3.7678
# step 1940: train loss 3.6581, val loss 3.7972
# step 1950: train loss 3.6271, val loss 3.6438
# step 1960: train loss 3.6641, val loss 3.7299
# step 1970: train loss 3.5748, val loss 3.7257
# step 1980: train loss 3.6592, val loss 3.7824
# step 1990: train loss 3.6730, val loss 3.6873
# step 2000: train loss 3.6132, val loss 3.7245
# step 2010: train loss 3.6300, val loss 3.7097
# step 2020: train loss 3.5975, val loss 3.8660
# step 2030: train loss 3.6697, val loss 3.7187
# step 2040: train loss 3.5308, val loss 3.7034
# step 2050: train loss 3.6277, val loss 3.6417
# step 2060: train loss 3.6052, val loss 3.6988
# step 2070: train loss 3.6395, val loss 3.7020
# step 2080: train loss 3.5818, val loss 3.6433
# step 2090: train loss 3.6386, val loss 3.5747
# step 2100: train loss 3.5433, val loss 3.6719
# step 2110: train loss 3.5398, val loss 3.5924
# step 2120: train loss 3.5422, val loss 3.7295
# step 2130: train loss 3.5314, val loss 3.6805
# step 2140: train loss 3.5849, val loss 3.5925
# step 2150: train loss 3.6238, val loss 3.7010
# step 2160: train loss 3.5856, val loss 3.6427
# step 2170: train loss 3.5379, val loss 3.6532
# step 2180: train loss 3.5045, val loss 3.5887
# step 2190: train loss 3.5008, val loss 3.5942
# step 2200: train loss 3.5461, val loss 3.6988
# step 2210: train loss 3.5578, val loss 3.5538
# step 2220: train loss 3.5516, val loss 3.5992
# step 2230: train loss 3.4548, val loss 3.5925
# step 2240: train loss 3.5097, val loss 3.4776
# step 2250: train loss 3.5528, val loss 3.6172
# step 2260: train loss 3.5223, val loss 3.5843
# step 2270: train loss 3.5480, val loss 3.5236
# step 2280: train loss 3.5080, val loss 3.5605
# step 2290: train loss 3.5716, val loss 3.6126
# step 2300: train loss 3.5313, val loss 3.6200
# step 2310: train loss 3.4693, val loss 3.5973
# step 2320: train loss 3.5235, val loss 3.5816
# step 2330: train loss 3.5297, val loss 3.5756
# step 2340: train loss 3.4617, val loss 3.5226
# step 2350: train loss 3.4323, val loss 3.5455
# step 2360: train loss 3.4571, val loss 3.5185
# step 2370: train loss 3.4619, val loss 3.5188
# step 2380: train loss 3.4893, val loss 3.5180
# step 2390: train loss 3.5021, val loss 3.5589
# step 2400: train loss 3.5057, val loss 3.4964
# step 2410: train loss 3.4467, val loss 3.5996
# step 2420: train loss 3.4695, val loss 3.5678
# step 2430: train loss 3.5247, val loss 3.5319
# step 2440: train loss 3.4375, val loss 3.5780
# step 2450: train loss 3.4488, val loss 3.4511
# step 2460: train loss 3.4227, val loss 3.5132
# step 2470: train loss 3.4014, val loss 3.4860
# step 2480: train loss 3.4879, val loss 3.4847
# step 2490: train loss 3.4677, val loss 3.5067
# step 2500: train loss 3.4073, val loss 3.5313
# step 2510: train loss 3.4088, val loss 3.5301
# step 2520: train loss 3.4018, val loss 3.5050
# step 2530: train loss 3.4639, val loss 3.5709
# step 2540: train loss 3.4078, val loss 3.5293
# step 2550: train loss 3.4022, val loss 3.5646
# step 2560: train loss 3.3497, val loss 3.4015
# step 2570: train loss 3.3428, val loss 3.4882
# step 2580: train loss 3.4159, val loss 3.4925
# step 2590: train loss 3.4034, val loss 3.4276
# step 2600: train loss 3.4295, val loss 3.5318
# step 2610: train loss 3.3710, val loss 3.4503
# step 2620: train loss 3.3971, val loss 3.4050
# step 2630: train loss 3.3253, val loss 3.4547
# step 2640: train loss 3.4206, val loss 3.4609
# step 2650: train loss 3.2923, val loss 3.4897
# step 2660: train loss 3.3410, val loss 3.4224
# step 2670: train loss 3.3811, val loss 3.4454
# step 2680: train loss 3.2941, val loss 3.4155
# step 2690: train loss 3.2968, val loss 3.3562
# step 2700: train loss 3.3139, val loss 3.4092
# step 2710: train loss 3.4208, val loss 3.2531
# step 2720: train loss 3.3700, val loss 3.3980
# step 2730: train loss 3.2949, val loss 3.4521
# step 2740: train loss 3.2923, val loss 3.3841
# step 2750: train loss 3.3818, val loss 3.4569
# step 2760: train loss 3.3695, val loss 3.4344
# step 2770: train loss 3.3759, val loss 3.3846
# step 2780: train loss 3.3095, val loss 3.4078
# step 2790: train loss 3.3247, val loss 3.4094
# step 2800: train loss 3.3395, val loss 3.3154
# step 2810: train loss 3.2717, val loss 3.4093
# step 2820: train loss 3.2891, val loss 3.4020
# step 2830: train loss 3.3348, val loss 3.3962
# step 2840: train loss 3.2610, val loss 3.3823
# step 2850: train loss 3.2963, val loss 3.3467
# step 2860: train loss 3.2499, val loss 3.3659
# step 2870: train loss 3.2587, val loss 3.3823
# step 2880: train loss 3.2759, val loss 3.3221
# step 2890: train loss 3.2749, val loss 3.2529
# step 2900: train loss 3.2792, val loss 3.3018
# step 2910: train loss 3.3053, val loss 3.3343
# step 2920: train loss 3.3228, val loss 3.3881
# step 2930: train loss 3.2735, val loss 3.3470
# step 2940: train loss 3.1780, val loss 3.3667
# step 2950: train loss 3.2298, val loss 3.3715
# step 2960: train loss 3.2364, val loss 3.3433
# step 2970: train loss 3.2278, val loss 3.2930
# step 2980: train loss 3.1967, val loss 3.2717
# step 2990: train loss 3.2269, val loss 3.3137
# step 3000: train loss 3.2289, val loss 3.1967
# step 3010: train loss 3.2691, val loss 3.3618
# step 3020: train loss 3.1955, val loss 3.3960
# step 3030: train loss 3.3091, val loss 3.2566
# step 3040: train loss 3.2126, val loss 3.3164
# step 3050: train loss 3.2612, val loss 3.3530
# step 3060: train loss 3.2471, val loss 3.2554
# step 3070: train loss 3.1706, val loss 3.2695
# step 3080: train loss 3.2008, val loss 3.3274
# step 3090: train loss 3.1864, val loss 3.3111
# step 3100: train loss 3.2294, val loss 3.2991
# step 3110: train loss 3.2154, val loss 3.2600
# step 3120: train loss 3.1759, val loss 3.1900
# step 3130: train loss 3.1830, val loss 3.2190
# step 3140: train loss 3.2478, val loss 3.2745
# step 3150: train loss 3.1504, val loss 3.1982
# step 3160: train loss 3.1407, val loss 3.2431
# step 3170: train loss 3.2455, val loss 3.2741
# step 3180: train loss 3.2483, val loss 3.2697
# step 3190: train loss 3.2533, val loss 3.2720
# step 3200: train loss 3.1870, val loss 3.3209
# step 3210: train loss 3.2253, val loss 3.1523
# step 3220: train loss 3.1060, val loss 3.1782
# step 3230: train loss 3.1300, val loss 3.2713
# step 3240: train loss 3.1798, val loss 3.2585
# step 3250: train loss 3.1117, val loss 3.3333
# step 3260: train loss 3.2891, val loss 3.3073
# step 3270: train loss 3.1126, val loss 3.2400
# step 3280: train loss 3.2588, val loss 3.2179
# step 3290: train loss 3.2006, val loss 3.1154
# step 3300: train loss 3.1481, val loss 3.2557
# step 3310: train loss 3.1319, val loss 3.2765
# step 3320: train loss 3.1167, val loss 3.2400
# step 3330: train loss 3.1698, val loss 3.2639
# step 3340: train loss 3.1942, val loss 3.1760
# step 3350: train loss 3.1905, val loss 3.1999
# step 3360: train loss 3.0696, val loss 3.2576
# step 3370: train loss 3.1446, val loss 3.2469
# step 3380: train loss 3.1035, val loss 3.2830
# step 3390: train loss 3.1595, val loss 3.2041
# step 3400: train loss 3.1318, val loss 3.2167
# step 3410: train loss 3.1121, val loss 3.2511
# step 3420: train loss 3.1164, val loss 3.1476
# step 3430: train loss 3.1544, val loss 3.2136
# step 3440: train loss 3.1311, val loss 3.2748
# step 3450: train loss 3.0273, val loss 3.1888
# step 3460: train loss 3.1254, val loss 3.1754
# step 3470: train loss 3.1616, val loss 3.1158
# step 3480: train loss 3.1183, val loss 3.2632
# step 3490: train loss 3.1411, val loss 3.1285
# step 3500: train loss 3.1068, val loss 3.1175
# step 3510: train loss 3.0951, val loss 3.2171
# step 3520: train loss 3.0344, val loss 3.1236
# step 3530: train loss 3.0655, val loss 3.2129
# step 3540: train loss 3.0854, val loss 3.1771
# step 3550: train loss 3.0759, val loss 3.3356
# step 3560: train loss 3.1349, val loss 3.3109
# step 3570: train loss 3.0858, val loss 3.2662
# step 3580: train loss 3.0697, val loss 3.1826
# step 3590: train loss 3.0922, val loss 3.1328
# step 3600: train loss 3.0205, val loss 3.1903
# step 3610: train loss 3.0973, val loss 3.1102
# step 3620: train loss 3.1012, val loss 3.2045
# step 3630: train loss 2.9961, val loss 3.2058
# step 3640: train loss 3.1058, val loss 3.1171
# step 3650: train loss 3.0642, val loss 3.1295
# step 3660: train loss 3.0996, val loss 3.1253
# step 3670: train loss 3.0962, val loss 3.2197
# step 3680: train loss 3.0814, val loss 3.1199
# step 3690: train loss 3.0786, val loss 3.1014
# step 3700: train loss 3.1037, val loss 3.2763
# step 3710: train loss 3.0352, val loss 3.0915
# step 3720: train loss 3.0709, val loss 3.1248
# step 3730: train loss 3.0519, val loss 3.1807
# step 3740: train loss 3.0591, val loss 3.1194
# step 3750: train loss 3.0583, val loss 3.1626
# step 3760: train loss 3.0406, val loss 3.1027
# step 3770: train loss 3.0489, val loss 3.1011
# step 3780: train loss 3.0043, val loss 3.0702
# step 3790: train loss 3.0172, val loss 3.2331
# step 3800: train loss 2.9984, val loss 3.1056
# step 3810: train loss 2.9859, val loss 2.9820
# step 3820: train loss 3.1111, val loss 3.0683
# step 3830: train loss 2.9821, val loss 3.0778
# step 3840: train loss 3.0383, val loss 3.1025
# step 3850: train loss 2.9725, val loss 2.9907
# step 3860: train loss 2.9958, val loss 3.0203
# step 3870: train loss 3.0054, val loss 3.0920
# step 3880: train loss 2.9328, val loss 3.1287
# step 3890: train loss 2.9904, val loss 3.0640
# step 3900: train loss 2.9738, val loss 3.0594
# step 3910: train loss 3.0278, val loss 3.1254
# step 3920: train loss 2.9223, val loss 3.0436
# step 3930: train loss 2.9881, val loss 3.1446
# step 3940: train loss 2.9825, val loss 3.0756
# step 3950: train loss 2.9818, val loss 3.0217
# step 3960: train loss 3.0482, val loss 3.1903
# step 3970: train loss 2.9776, val loss 3.0413
# step 3980: train loss 3.0527, val loss 3.1058
# step 3990: train loss 2.9789, val loss 3.1228
# step 4000: train loss 2.9864, val loss 3.1658
# step 4010: train loss 2.9785, val loss 2.9884
# step 4020: train loss 3.0266, val loss 3.0865
# step 4030: train loss 2.9890, val loss 3.1353
# step 4040: train loss 3.0427, val loss 3.0002
# step 4050: train loss 2.9078, val loss 3.0627
# step 4060: train loss 2.9616, val loss 3.1170
# step 4070: train loss 2.9606, val loss 2.9278
# step 4080: train loss 3.0421, val loss 3.0125
# step 4090: train loss 2.9348, val loss 3.1580
# step 4100: train loss 2.9956, val loss 3.0722
# step 4110: train loss 2.9598, val loss 3.0049
# step 4120: train loss 3.0069, val loss 3.1298
# step 4130: train loss 2.9435, val loss 2.9361
# step 4140: train loss 2.9333, val loss 3.0780
# step 4150: train loss 2.9951, val loss 2.9933
# step 4160: train loss 3.0544, val loss 3.0183
# step 4170: train loss 2.9214, val loss 2.9965
# step 4180: train loss 2.9076, val loss 3.0872
# step 4190: train loss 2.8718, val loss 2.9931
# step 4200: train loss 2.9448, val loss 2.9642
# step 4210: train loss 2.9875, val loss 3.0003
# step 4220: train loss 2.9796, val loss 3.1069
# step 4230: train loss 2.8838, val loss 3.0043
# step 4240: train loss 2.8569, val loss 3.0453
# step 4250: train loss 2.9621, val loss 3.0802
# step 4260: train loss 2.8988, val loss 2.9765
# step 4270: train loss 2.9519, val loss 3.0885
# step 4280: train loss 2.8384, val loss 3.0666
# step 4290: train loss 2.8883, val loss 3.1751
# step 4300: train loss 2.9866, val loss 2.9704
# step 4310: train loss 2.8733, val loss 3.0767
# step 4320: train loss 2.9111, val loss 3.0516
# step 4330: train loss 2.9947, val loss 3.0088
# step 4340: train loss 2.8841, val loss 3.1519
# step 4350: train loss 2.9847, val loss 2.9765
# step 4360: train loss 2.9155, val loss 2.9318
# step 4370: train loss 2.9275, val loss 2.9579
# step 4380: train loss 2.9374, val loss 2.9933
# step 4390: train loss 2.8807, val loss 2.8946
# step 4400: train loss 2.9421, val loss 2.9984
# step 4410: train loss 2.8811, val loss 2.9801
# step 4420: train loss 2.9530, val loss 2.9770
# step 4430: train loss 2.9021, val loss 2.8891
# step 4440: train loss 2.8731, val loss 3.0265
# step 4450: train loss 2.9159, val loss 2.9585
# step 4460: train loss 2.8770, val loss 2.8682
# step 4470: train loss 2.8726, val loss 2.9125
# step 4480: train loss 2.8227, val loss 3.0635
# step 4490: train loss 2.9506, val loss 2.9562
# step 4500: train loss 2.9027, val loss 2.8766
# step 4510: train loss 2.9391, val loss 2.9289
# step 4520: train loss 2.8698, val loss 2.9635
# step 4530: train loss 2.8184, val loss 3.0913
# step 4540: train loss 2.9270, val loss 3.0315
# step 4550: train loss 2.8102, val loss 2.9014
# step 4560: train loss 2.9263, val loss 3.0063
# step 4570: train loss 2.9418, val loss 2.9700
# step 4580: train loss 2.8778, val loss 3.0514
# step 4590: train loss 2.9509, val loss 2.9583
# step 4600: train loss 2.8816, val loss 2.9483
# step 4610: train loss 2.9809, val loss 2.9203
# step 4620: train loss 2.8945, val loss 2.9610
# step 4630: train loss 2.8401, val loss 2.9055
# step 4640: train loss 2.8497, val loss 2.8924
# step 4650: train loss 2.8141, val loss 2.9486
# step 4660: train loss 2.8553, val loss 2.9907
# step 4670: train loss 2.9188, val loss 3.0043
# step 4680: train loss 2.9003, val loss 2.9649
# step 4690: train loss 2.8893, val loss 2.9296
# step 4700: train loss 2.8916, val loss 3.0794
# step 4710: train loss 2.8593, val loss 2.9144
# step 4720: train loss 2.9355, val loss 2.9629
# step 4730: train loss 2.7612, val loss 2.9497
# step 4740: train loss 2.8971, val loss 2.8989
# step 4750: train loss 2.8330, val loss 2.9530
# step 4760: train loss 2.9267, val loss 2.8922
# step 4770: train loss 2.7290, val loss 3.0241
# step 4780: train loss 2.8269, val loss 2.9065
# step 4790: train loss 2.8610, val loss 2.8878
# step 4800: train loss 2.7985, val loss 2.9289
# step 4810: train loss 2.7906, val loss 2.8503
# step 4820: train loss 2.7295, val loss 2.9103
# step 4830: train loss 2.8687, val loss 2.8930
# step 4840: train loss 2.8733, val loss 2.8529
# step 4850: train loss 2.8387, val loss 2.9488
# step 4860: train loss 2.8220, val loss 2.9678
# step 4870: train loss 2.8593, val loss 3.0319
# step 4880: train loss 2.8845, val loss 2.9564
# step 4890: train loss 2.8664, val loss 2.9558
# step 4900: train loss 2.8535, val loss 2.8858
# step 4910: train loss 2.7647, val loss 2.8698
# step 4920: train loss 2.8586, val loss 2.8765
# step 4930: train loss 2.7955, val loss 2.9661
# step 4940: train loss 2.7608, val loss 2.9593
# step 4950: train loss 2.8423, val loss 2.8946
# step 4960: train loss 2.8749, val loss 2.8859
# step 4970: train loss 2.8853, val loss 2.8339
# step 4980: train loss 2.8945, val loss 2.9162
# step 4990: train loss 2.8336, val loss 2.9071
# step 5000: train loss 2.7807, val loss 2.9281
# step 5010: train loss 2.8325, val loss 2.7360
# step 5020: train loss 2.8552, val loss 2.8172
# step 5030: train loss 2.8129, val loss 2.9454
# step 5040: train loss 2.7960, val loss 2.8123
# step 5050: train loss 2.8553, val loss 2.9005
# step 5060: train loss 2.8630, val loss 2.8640
# step 5070: train loss 2.8333, val loss 2.8650
# step 5080: train loss 2.8673, val loss 2.8318
# step 5090: train loss 2.8300, val loss 2.7838
# step 5100: train loss 2.9035, val loss 2.7929
# step 5110: train loss 2.7947, val loss 2.8978
# step 5120: train loss 2.8239, val loss 2.8969
# step 5130: train loss 2.7665, val loss 2.9777
# step 5140: train loss 2.7859, val loss 2.9826
# step 5150: train loss 2.7266, val loss 2.8559
# step 5160: train loss 2.7399, val loss 2.8445
# step 5170: train loss 2.7159, val loss 2.9338
# step 5180: train loss 2.8650, val loss 2.9412
# step 5190: train loss 2.8393, val loss 2.9000
# step 5200: train loss 2.8427, val loss 3.0151
# step 5210: train loss 2.7743, val loss 2.8661
# step 5220: train loss 2.7376, val loss 2.9488
# step 5230: train loss 2.7585, val loss 2.7849
# step 5240: train loss 2.8161, val loss 2.8065
# step 5250: train loss 2.7747, val loss 2.7575
# step 5260: train loss 2.7392, val loss 2.7256
# step 5270: train loss 2.7299, val loss 2.6947
# step 5280: train loss 2.8163, val loss 2.9078
# step 5290: train loss 2.7200, val loss 2.9099
# step 5300: train loss 2.7307, val loss 2.8767
# step 5310: train loss 2.8309, val loss 2.8570
# step 5320: train loss 2.8053, val loss 2.7957
# step 5330: train loss 2.8339, val loss 2.7587
# step 5340: train loss 2.7598, val loss 2.8931
# step 5350: train loss 2.7809, val loss 2.8284
# step 5360: train loss 2.6856, val loss 2.7639
# step 5370: train loss 2.7494, val loss 2.8871
# step 5380: train loss 2.7135, val loss 2.9101
# step 5390: train loss 2.7356, val loss 2.8136
# step 5400: train loss 2.7240, val loss 2.7574
# step 5410: train loss 2.6984, val loss 2.8226
# step 5420: train loss 2.7135, val loss 2.8847
# step 5430: train loss 2.7732, val loss 2.8305
# step 5440: train loss 2.7591, val loss 2.8544
# step 5450: train loss 2.7223, val loss 2.6952
# step 5460: train loss 2.7571, val loss 2.7681
# step 5470: train loss 2.7371, val loss 2.8814
# step 5480: train loss 2.7380, val loss 2.8096
# step 5490: train loss 2.6791, val loss 2.8024
# step 5500: train loss 2.7240, val loss 2.8911
# step 5510: train loss 2.7012, val loss 2.8552
# step 5520: train loss 2.7928, val loss 2.8481
# step 5530: train loss 2.7966, val loss 2.8382
# step 5540: train loss 2.7748, val loss 2.8222
# step 5550: train loss 2.7390, val loss 2.7991
# step 5560: train loss 2.7675, val loss 2.8341
# step 5570: train loss 2.8045, val loss 2.9588
# step 5580: train loss 2.7795, val loss 2.8642
# step 5590: train loss 2.7250, val loss 2.8189
# step 5600: train loss 2.7862, val loss 2.8595
# step 5610: train loss 2.7075, val loss 2.8611
# step 5620: train loss 2.6846, val loss 2.8682
# step 5630: train loss 2.7501, val loss 2.7759
# step 5640: train loss 2.6624, val loss 2.8324
# step 5650: train loss 2.6556, val loss 2.7892
# step 5660: train loss 2.7998, val loss 2.6613
# step 5670: train loss 2.7201, val loss 2.8113
# step 5680: train loss 2.7075, val loss 2.7626
# step 5690: train loss 2.6447, val loss 2.7489
# step 5700: train loss 2.7357, val loss 2.7291
# step 5710: train loss 2.7218, val loss 2.7847
# step 5720: train loss 2.6701, val loss 2.7797
# step 5730: train loss 2.7125, val loss 2.7415
# step 5740: train loss 2.7544, val loss 2.7848
# step 5750: train loss 2.7297, val loss 2.7812
# step 5760: train loss 2.6615, val loss 2.7390
# step 5770: train loss 2.7774, val loss 2.7560
# step 5780: train loss 2.6163, val loss 2.7521
# step 5790: train loss 2.7236, val loss 2.8030
# step 5800: train loss 2.7644, val loss 2.6782
# step 5810: train loss 2.7042, val loss 2.8408
# step 5820: train loss 2.6984, val loss 2.8212
# step 5830: train loss 2.7015, val loss 2.7453
# step 5840: train loss 2.7644, val loss 2.7249
# step 5850: train loss 2.7588, val loss 2.7364
# step 5860: train loss 2.7007, val loss 2.7142
# step 5870: train loss 2.6495, val loss 2.8287
# step 5880: train loss 2.7810, val loss 2.7183
# step 5890: train loss 2.7384, val loss 2.7245
# step 5900: train loss 2.6654, val loss 2.8056
# step 5910: train loss 2.6812, val loss 2.8774
# step 5920: train loss 2.7257, val loss 2.8690
# step 5930: train loss 2.6880, val loss 2.8375
# step 5940: train loss 2.6805, val loss 2.8432
# step 5950: train loss 2.6318, val loss 2.6850
# step 5960: train loss 2.7232, val loss 2.7092
# step 5970: train loss 2.7222, val loss 2.8166
# step 5980: train loss 2.7189, val loss 2.8362
# step 5990: train loss 2.8330, val loss 2.9076
# step 6000: train loss 2.6858, val loss 2.7472
# step 6010: train loss 2.6782, val loss 2.8149
# step 6020: train loss 2.6788, val loss 2.7459
# step 6030: train loss 2.6329, val loss 2.7194
# step 6040: train loss 2.7786, val loss 2.8225
# step 6050: train loss 2.6671, val loss 2.7724
# step 6060: train loss 2.6720, val loss 2.7310
# step 6070: train loss 2.7344, val loss 2.7677
# step 6080: train loss 2.7315, val loss 2.7811
# step 6090: train loss 2.6983, val loss 2.7726
# step 6100: train loss 2.7205, val loss 2.8094
# step 6110: train loss 2.6267, val loss 2.7821
# step 6120: train loss 2.6653, val loss 2.7925
# step 6130: train loss 2.7300, val loss 2.7472
# step 6140: train loss 2.6539, val loss 2.7792
# step 6150: train loss 2.6911, val loss 2.8104
# step 6160: train loss 2.6282, val loss 2.8312
# step 6170: train loss 2.6253, val loss 2.7044
# step 6180: train loss 2.6684, val loss 2.7787
# step 6190: train loss 2.7190, val loss 2.7734
# step 6200: train loss 2.7104, val loss 2.6450
# step 6210: train loss 2.6563, val loss 2.7764
# step 6220: train loss 2.6789, val loss 2.6897
# step 6230: train loss 2.7364, val loss 2.7010
# step 6240: train loss 2.6720, val loss 2.8309
# step 6250: train loss 2.6502, val loss 2.7444
# step 6260: train loss 2.6287, val loss 2.7368
# step 6270: train loss 2.6104, val loss 2.7472
# step 6280: train loss 2.6136, val loss 2.7409
# step 6290: train loss 2.6414, val loss 2.7911
# step 6300: train loss 2.6323, val loss 2.7248
# step 6310: train loss 2.5587, val loss 2.7646
# step 6320: train loss 2.7223, val loss 2.7269
# step 6330: train loss 2.6405, val loss 2.7633
# step 6340: train loss 2.7658, val loss 2.7098
# step 6350: train loss 2.6926, val loss 2.7377
# step 6360: train loss 2.6884, val loss 2.7706
# step 6370: train loss 2.5770, val loss 2.8873
# step 6380: train loss 2.6142, val loss 2.7921
# step 6390: train loss 2.6415, val loss 2.6893
# step 6400: train loss 2.6496, val loss 2.6293
# step 6410: train loss 2.6070, val loss 2.6615
# step 6420: train loss 2.6634, val loss 2.6970
# step 6430: train loss 2.7377, val loss 2.6331
# step 6440: train loss 2.7149, val loss 2.7565
# step 6450: train loss 2.7039, val loss 2.7904
# step 6460: train loss 2.6105, val loss 2.6538
# step 6470: train loss 2.6547, val loss 2.8046
# step 6480: train loss 2.7038, val loss 2.6898
# step 6490: train loss 2.6525, val loss 2.8451
# step 6500: train loss 2.6821, val loss 2.7256
# step 6510: train loss 2.5604, val loss 2.7151
# step 6520: train loss 2.7253, val loss 2.7611
# step 6530: train loss 2.5695, val loss 2.6586
# step 6540: train loss 2.6019, val loss 2.7694
# step 6550: train loss 2.6351, val loss 2.6307
# step 6560: train loss 2.6242, val loss 2.7631
# step 6570: train loss 2.6785, val loss 2.7915
# step 6580: train loss 2.6112, val loss 2.6954
# step 6590: train loss 2.5915, val loss 2.7668
# step 6600: train loss 2.6323, val loss 2.7792
# step 6610: train loss 2.7025, val loss 2.7324
# step 6620: train loss 2.7137, val loss 2.7849
# step 6630: train loss 2.6250, val loss 2.7115
# step 6640: train loss 2.6092, val loss 2.7294
# step 6650: train loss 2.5931, val loss 2.7262
# step 6660: train loss 2.5703, val loss 2.7690
# step 6670: train loss 2.6764, val loss 2.7261
# step 6680: train loss 2.5256, val loss 2.7267
# step 6690: train loss 2.6147, val loss 2.7459
# step 6700: train loss 2.6514, val loss 2.8462
# step 6710: train loss 2.6310, val loss 2.7829
# step 6720: train loss 2.6745, val loss 2.6757
# step 6730: train loss 2.6154, val loss 2.7098
# step 6740: train loss 2.5697, val loss 2.6852
# step 6750: train loss 2.6560, val loss 2.7392
# step 6760: train loss 2.5894, val loss 2.7169
# step 6770: train loss 2.5894, val loss 2.6691
# step 6780: train loss 2.6266, val loss 2.7325
# step 6790: train loss 2.6725, val loss 2.6823
# step 6800: train loss 2.6924, val loss 2.7324
# step 6810: train loss 2.6252, val loss 2.7696
# step 6820: train loss 2.5657, val loss 2.7320
# step 6830: train loss 2.6054, val loss 2.7634
# step 6840: train loss 2.5556, val loss 2.7534
# step 6850: train loss 2.6374, val loss 2.8114
# step 6860: train loss 2.6086, val loss 2.6829
# step 6870: train loss 2.5720, val loss 2.7156
# step 6880: train loss 2.5980, val loss 2.6520
# step 6890: train loss 2.6537, val loss 2.7937
# step 6900: train loss 2.6427, val loss 2.6217
# step 6910: train loss 2.6940, val loss 2.6606
# step 6920: train loss 2.5292, val loss 2.7099
# step 6930: train loss 2.6306, val loss 2.6354
# step 6940: train loss 2.6023, val loss 2.8052
# step 6950: train loss 2.6891, val loss 2.8263
# step 6960: train loss 2.6053, val loss 2.6256
# step 6970: train loss 2.6579, val loss 2.8109
# step 6980: train loss 2.7067, val loss 2.6887
# step 6990: train loss 2.6314, val loss 2.7561
# step 7000: train loss 2.6554, val loss 2.8081
# step 7010: train loss 2.6631, val loss 2.6126
# step 7020: train loss 2.6120, val loss 2.6445
# step 7030: train loss 2.5942, val loss 2.7102
# step 7040: train loss 2.5118, val loss 2.6114
# step 7050: train loss 2.6262, val loss 2.6834
# step 7060: train loss 2.7001, val loss 2.7505
# step 7070: train loss 2.6441, val loss 2.6765
# step 7080: train loss 2.5600, val loss 2.7018
# step 7090: train loss 2.5926, val loss 2.7206
# step 7100: train loss 2.5855, val loss 2.8078
# step 7110: train loss 2.5261, val loss 2.6353
# step 7120: train loss 2.6001, val loss 2.7149
# step 7130: train loss 2.5779, val loss 2.7131
# step 7140: train loss 2.6037, val loss 2.7370
# step 7150: train loss 2.5101, val loss 2.6554
# step 7160: train loss 2.5552, val loss 2.6148
# step 7170: train loss 2.5750, val loss 2.7769
# step 7180: train loss 2.6217, val loss 2.7330
# step 7190: train loss 2.6179, val loss 2.8380
# step 7200: train loss 2.5969, val loss 2.5835
# step 7210: train loss 2.5782, val loss 2.7309
# step 7220: train loss 2.5758, val loss 2.6387
# step 7230: train loss 2.6352, val loss 2.6017
# step 7240: train loss 2.5830, val loss 2.7167
# step 7250: train loss 2.5361, val loss 2.7691
# step 7260: train loss 2.6202, val loss 2.6836
# step 7270: train loss 2.6043, val loss 2.7164
# step 7280: train loss 2.6858, val loss 2.6677
# step 7290: train loss 2.5817, val loss 2.7294
# step 7300: train loss 2.5870, val loss 2.6501
# step 7310: train loss 2.6032, val loss 2.6546
# step 7320: train loss 2.5763, val loss 2.8175
# step 7330: train loss 2.5451, val loss 2.6660
# step 7340: train loss 2.5839, val loss 2.6836
# step 7350: train loss 2.5763, val loss 2.6645
# step 7360: train loss 2.6035, val loss 2.6925
# step 7370: train loss 2.4854, val loss 2.6809
# step 7380: train loss 2.5629, val loss 2.6864
# step 7390: train loss 2.5931, val loss 2.6170
# step 7400: train loss 2.5633, val loss 2.6239
# step 7410: train loss 2.5732, val loss 2.6984
# step 7420: train loss 2.5736, val loss 2.7145
# step 7430: train loss 2.6019, val loss 2.6964
# step 7440: train loss 2.5971, val loss 2.5655
# step 7450: train loss 2.6040, val loss 2.6681
# step 7460: train loss 2.5723, val loss 2.7128
# step 7470: train loss 2.5362, val loss 2.6670
# step 7480: train loss 2.5730, val loss 2.6149
# step 7490: train loss 2.4896, val loss 2.6025
# step 7500: train loss 2.5872, val loss 2.7759
# step 7510: train loss 2.5997, val loss 2.5961
# step 7520: train loss 2.6360, val loss 2.7180
# step 7530: train loss 2.5252, val loss 2.7917
# step 7540: train loss 2.5471, val loss 2.6125
# step 7550: train loss 2.4961, val loss 2.6104
# step 7560: train loss 2.5993, val loss 2.6764
# step 7570: train loss 2.6440, val loss 2.5592
# step 7580: train loss 2.5319, val loss 2.6990
# step 7590: train loss 2.5935, val loss 2.5596
# step 7600: train loss 2.6345, val loss 2.6727
# step 7610: train loss 2.5555, val loss 2.6409
# step 7620: train loss 2.5780, val loss 2.7675
# step 7630: train loss 2.5553, val loss 2.7674
# step 7640: train loss 2.5545, val loss 2.6394
# step 7650: train loss 2.5869, val loss 2.7521
# step 7660: train loss 2.5994, val loss 2.5437
# step 7670: train loss 2.5464, val loss 2.5809
# step 7680: train loss 2.6136, val loss 2.6439
# step 7690: train loss 2.5227, val loss 2.7121
# step 7700: train loss 2.5863, val loss 2.5626
# step 7710: train loss 2.5387, val loss 2.6299
# step 7720: train loss 2.6204, val loss 2.6047
# step 7730: train loss 2.5660, val loss 2.6265
# step 7740: train loss 2.5799, val loss 2.6380
# step 7750: train loss 2.6345, val loss 2.6915
# step 7760: train loss 2.4798, val loss 2.6866
# step 7770: train loss 2.6114, val loss 2.6855
# step 7780: train loss 2.5328, val loss 2.6687
# step 7790: train loss 2.5529, val loss 2.6892
# step 7800: train loss 2.5235, val loss 2.5882
# step 7810: train loss 2.6609, val loss 2.7455
# step 7820: train loss 2.5714, val loss 2.6858
# step 7830: train loss 2.5865, val loss 2.5780
# step 7840: train loss 2.5956, val loss 2.5316
# step 7850: train loss 2.5588, val loss 2.6845
# step 7860: train loss 2.6048, val loss 2.7272
# step 7870: train loss 2.5824, val loss 2.6459
# step 7880: train loss 2.6238, val loss 2.6384
# step 7890: train loss 2.5516, val loss 2.5789
# step 7900: train loss 2.6305, val loss 2.6003
# step 7910: train loss 2.4859, val loss 2.6369
# step 7920: train loss 2.6203, val loss 2.6522
# step 7930: train loss 2.5562, val loss 2.6895
# step 7940: train loss 2.5510, val loss 2.6150
# step 7950: train loss 2.5604, val loss 2.6267
# step 7960: train loss 2.6691, val loss 2.6566
# step 7970: train loss 2.5927, val loss 2.6300
# step 7980: train loss 2.5664, val loss 2.6414
# step 7990: train loss 2.5299, val loss 2.6908
# step 8000: train loss 2.5222, val loss 2.7057
# step 8010: train loss 2.5296, val loss 2.5879
# step 8020: train loss 2.5643, val loss 2.6555
# step 8030: train loss 2.5987, val loss 2.6144
# step 8040: train loss 2.6491, val loss 2.5165
# step 8050: train loss 2.6086, val loss 2.6443
# step 8060: train loss 2.5462, val loss 2.5405
# step 8070: train loss 2.5836, val loss 2.5994
# step 8080: train loss 2.4645, val loss 2.5994
# step 8090: train loss 2.5894, val loss 2.5860
# step 8100: train loss 2.5333, val loss 2.6458
# step 8110: train loss 2.5187, val loss 2.6465
# step 8120: train loss 2.6098, val loss 2.6870
# step 8130: train loss 2.5656, val loss 2.4780
# step 8140: train loss 2.5541, val loss 2.6178
# step 8150: train loss 2.5320, val loss 2.5684
# step 8160: train loss 2.5313, val loss 2.5948
# step 8170: train loss 2.5307, val loss 2.6345
# step 8180: train loss 2.5680, val loss 2.6040
# step 8190: train loss 2.5229, val loss 2.6052
# step 8200: train loss 2.5935, val loss 2.7424
# step 8210: train loss 2.6541, val loss 2.5804
# step 8220: train loss 2.5339, val loss 2.5705
# step 8230: train loss 2.5721, val loss 2.6626
# step 8240: train loss 2.5411, val loss 2.5233
# step 8250: train loss 2.5839, val loss 2.6189
# step 8260: train loss 2.5082, val loss 2.6032
# step 8270: train loss 2.6483, val loss 2.6636
# step 8280: train loss 2.5950, val loss 2.6656
# step 8290: train loss 2.6132, val loss 2.6158
# step 8300: train loss 2.5999, val loss 2.7300
# step 8310: train loss 2.6307, val loss 2.6422
# step 8320: train loss 2.5605, val loss 2.5694
# step 8330: train loss 2.6120, val loss 2.5597
# step 8340: train loss 2.5568, val loss 2.6934
# step 8350: train loss 2.5297, val loss 2.6351
# step 8360: train loss 2.4849, val loss 2.6486
# step 8370: train loss 2.5702, val loss 2.6177
# step 8380: train loss 2.5007, val loss 2.6863
# step 8390: train loss 2.5317, val loss 2.7662
# step 8400: train loss 2.4484, val loss 2.5946
# step 8410: train loss 2.5520, val loss 2.5564
# step 8420: train loss 2.5199, val loss 2.6605
# step 8430: train loss 2.5300, val loss 2.6551
# step 8440: train loss 2.5156, val loss 2.6616
# step 8450: train loss 2.5157, val loss 2.5525
# step 8460: train loss 2.4873, val loss 2.5581
# step 8470: train loss 2.5770, val loss 2.5431
# step 8480: train loss 2.5448, val loss 2.6338
# step 8490: train loss 2.4948, val loss 2.6346
# step 8500: train loss 2.5246, val loss 2.7108
# step 8510: train loss 2.5317, val loss 2.6165
# step 8520: train loss 2.5549, val loss 2.4696
# step 8530: train loss 2.5604, val loss 2.5800
# step 8540: train loss 2.5805, val loss 2.3947
# step 8550: train loss 2.5250, val loss 2.5997
# step 8560: train loss 2.5787, val loss 2.5281
# step 8570: train loss 2.5567, val loss 2.6452
# step 8580: train loss 2.5715, val loss 2.6003
# step 8590: train loss 2.5304, val loss 2.6306
# step 8600: train loss 2.5282, val loss 2.6271
# step 8610: train loss 2.5299, val loss 2.5622
# step 8620: train loss 2.5900, val loss 2.5447
# step 8630: train loss 2.5213, val loss 2.6676
# step 8640: train loss 2.5038, val loss 2.6072
# step 8650: train loss 2.5660, val loss 2.6392
# step 8660: train loss 2.5409, val loss 2.6154
# step 8670: train loss 2.5840, val loss 2.6127
# step 8680: train loss 2.5494, val loss 2.5050
# step 8690: train loss 2.5757, val loss 2.5672
# step 8700: train loss 2.4943, val loss 2.4865
# step 8710: train loss 2.5283, val loss 2.5352
# step 8720: train loss 2.5457, val loss 2.5192
# step 8730: train loss 2.4707, val loss 2.5431
# step 8740: train loss 2.6114, val loss 2.6011
# step 8750: train loss 2.5637, val loss 2.5856
# step 8760: train loss 2.4991, val loss 2.6128
# step 8770: train loss 2.5661, val loss 2.5657
# step 8780: train loss 2.5464, val loss 2.5731
# step 8790: train loss 2.5303, val loss 2.6487
# step 8800: train loss 2.5483, val loss 2.6729
# step 8810: train loss 2.4517, val loss 2.6271
# step 8820: train loss 2.5254, val loss 2.5577
# step 8830: train loss 2.5494, val loss 2.6082
# step 8840: train loss 2.5042, val loss 2.5509
# step 8850: train loss 2.5062, val loss 2.7475
# step 8860: train loss 2.5284, val loss 2.5676
# step 8870: train loss 2.5282, val loss 2.6528
# step 8880: train loss 2.6202, val loss 2.5748
# step 8890: train loss 2.4704, val loss 2.5791
# step 8900: train loss 2.5433, val loss 2.6202
# step 8910: train loss 2.4727, val loss 2.6450
# step 8920: train loss 2.5629, val loss 2.5732
# step 8930: train loss 2.5557, val loss 2.6203
# step 8940: train loss 2.4465, val loss 2.6137
# step 8950: train loss 2.4636, val loss 2.5954
# step 8960: train loss 2.5261, val loss 2.6010
# step 8970: train loss 2.5542, val loss 2.6349
# step 8980: train loss 2.6109, val loss 2.5768
# step 8990: train loss 2.4657, val loss 2.6241
# step 9000: train loss 2.4801, val loss 2.5354
# step 9010: train loss 2.4934, val loss 2.6586
# step 9020: train loss 2.4353, val loss 2.5571
# step 9030: train loss 2.5152, val loss 2.6163
# step 9040: train loss 2.4875, val loss 2.5574
# step 9050: train loss 2.5026, val loss 2.5146
# step 9060: train loss 2.5489, val loss 2.7370
# step 9070: train loss 2.5331, val loss 2.5437
# step 9080: train loss 2.4799, val loss 2.5039
# step 9090: train loss 2.5681, val loss 2.6450
# step 9100: train loss 2.6158, val loss 2.6494
# step 9110: train loss 2.4816, val loss 2.6063
# step 9120: train loss 2.4643, val loss 2.5603
# step 9130: train loss 2.5378, val loss 2.5808
# step 9140: train loss 2.4769, val loss 2.6672
# step 9150: train loss 2.5649, val loss 2.5931
# step 9160: train loss 2.4985, val loss 2.5615
# step 9170: train loss 2.4430, val loss 2.5951
# step 9180: train loss 2.5541, val loss 2.5959
# step 9190: train loss 2.5248, val loss 2.6543
# step 9200: train loss 2.4571, val loss 2.4636
# step 9210: train loss 2.5148, val loss 2.6470
# step 9220: train loss 2.5095, val loss 2.5510
# step 9230: train loss 2.5379, val loss 2.6018
# step 9240: train loss 2.4790, val loss 2.6286
# step 9250: train loss 2.4935, val loss 2.5009
# step 9260: train loss 2.5389, val loss 2.6087
# step 9270: train loss 2.5440, val loss 2.6497
# step 9280: train loss 2.5232, val loss 2.4735
# step 9290: train loss 2.4650, val loss 2.5830
# step 9300: train loss 2.4915, val loss 2.5420
# step 9310: train loss 2.4349, val loss 2.4886
# step 9320: train loss 2.5573, val loss 2.6010
# step 9330: train loss 2.5012, val loss 2.6189
# step 9340: train loss 2.4253, val loss 2.6819
# step 9350: train loss 2.5079, val loss 2.6105
# step 9360: train loss 2.4705, val loss 2.5219
# step 9370: train loss 2.5327, val loss 2.6033
# step 9380: train loss 2.5863, val loss 2.6376
# step 9390: train loss 2.4677, val loss 2.5467
# step 9400: train loss 2.4975, val loss 2.5736
# step 9410: train loss 2.5153, val loss 2.5838
# step 9420: train loss 2.5093, val loss 2.5584
# step 9430: train loss 2.4454, val loss 2.6117
# step 9440: train loss 2.5479, val loss 2.5794
# step 9450: train loss 2.5523, val loss 2.6215
# step 9460: train loss 2.5604, val loss 2.5056
# step 9470: train loss 2.4893, val loss 2.5906
# step 9480: train loss 2.4493, val loss 2.5468
# step 9490: train loss 2.5425, val loss 2.5679
# step 9500: train loss 2.5412, val loss 2.6853
# step 9510: train loss 2.4749, val loss 2.4293
# step 9520: train loss 2.5190, val loss 2.5982
# step 9530: train loss 2.5043, val loss 2.6267
# step 9540: train loss 2.4182, val loss 2.5514
# step 9550: train loss 2.5077, val loss 2.6105
# step 9560: train loss 2.5713, val loss 2.5063
# step 9570: train loss 2.5182, val loss 2.5374
# step 9580: train loss 2.4449, val loss 2.5782
# step 9590: train loss 2.5121, val loss 2.5994
# step 9600: train loss 2.5261, val loss 2.6388
# step 9610: train loss 2.5169, val loss 2.5564
# step 9620: train loss 2.5326, val loss 2.5477
# step 9630: train loss 2.4526, val loss 2.4818
# step 9640: train loss 2.4506, val loss 2.5281
# step 9650: train loss 2.5435, val loss 2.6302
# step 9660: train loss 2.5065, val loss 2.5748
# step 9670: train loss 2.5332, val loss 2.5790
# step 9680: train loss 2.4475, val loss 2.6169
# step 9690: train loss 2.4201, val loss 2.5781
# step 9700: train loss 2.4072, val loss 2.6472
# step 9710: train loss 2.4465, val loss 2.6619
# step 9720: train loss 2.5704, val loss 2.6277
# step 9730: train loss 2.4930, val loss 2.6225
# step 9740: train loss 2.5162, val loss 2.8018
# step 9750: train loss 2.4868, val loss 2.5427
# step 9760: train loss 2.5185, val loss 2.5194
# step 9770: train loss 2.5217, val loss 2.5801
# step 9780: train loss 2.6280, val loss 2.6066
# step 9790: train loss 2.4983, val loss 2.5935
# step 9800: train loss 2.5404, val loss 2.5395
# step 9810: train loss 2.4918, val loss 2.5678
# step 9820: train loss 2.4909, val loss 2.4666
# step 9830: train loss 2.4106, val loss 2.6276
# step 9840: train loss 2.5150, val loss 2.6186
# step 9850: train loss 2.4916, val loss 2.4851
# step 9860: train loss 2.4934, val loss 2.5227
# step 9870: train loss 2.4709, val loss 2.5325
# step 9880: train loss 2.4644, val loss 2.5823
# step 9890: train loss 2.5305, val loss 2.5591
# step 9900: train loss 2.4859, val loss 2.4737
# step 9910: train loss 2.4122, val loss 2.5216
# step 9920: train loss 2.5202, val loss 2.4362
# step 9930: train loss 2.4828, val loss 2.6545
# step 9940: train loss 2.4588, val loss 2.5126
# step 9950: train loss 2.5222, val loss 2.5061
# step 9960: train loss 2.5175, val loss 2.5231
# step 9970: train loss 2.5539, val loss 2.5843
# step 9980: train loss 2.5612, val loss 2.5328
# step 9990: train loss 2.4578, val loss 2.6309

# %% [markdown]
# Une fois le réseau entrainé pendant 100 itérations, on peut générer une séquence de caractères.
#
# Questions :
# > * Quel est l'effet de l'entraînement ?
# > * Augmenter le nombre d'itérations à 1000 puis à 10,000, noter la loss obtenue et la phrase générée. Qu'observez-vous ?

# %%
idx = torch.ones((1,1), dtype=torch.long)*3
print (decode(m.generate(idx, max_new_tokens=100)[0].tolist()))
# Out:
# Nis :D
# De ventoutme l pj1k?cest, vêvita pense n Fi?
# IEQUME
# Fant dane d hesRja scolténuvarqurouset res

# %% [markdown]
# 100 itérations : aucun effet de l'entrainement. On a juste des espaces en plus.
#
# 1000 itérations : peu de différence, toujours incompréhensible.
#
# 10 000 itérations : pas de vrais mots mais la structure dans l'espace ressemble à un poème (retours à la lignes, ponctuation en fin de phrase, espaces réguliers, des mots qui ne veulent rien dire mais qui sont lisibles)

# %% [markdown]
# ## Single Head Attention
#
# Nous allons maintenant implémenter le mécanisme de base de l'attention. Pour chaque couple de mots de la séquence, ce mécanisme combine Q une *query* (l'information recherchée), K une *key* (l'information obtenue) et calcule  V une *value*, un vecteur de résultat.
#
# ![single head attention](images/single_head_attention.png)
#
# ### Masquage
# Cependant, comme nous utilisons le modèle pour générer des séquences, on ne doit pas utiliser les caractères situés après le caractère courant, car ce sont justement ces caractères que l'on cherche à prédire lors de l'apprentissage : *le futur n'est pas utilisé pour prédire (le futur).*
#
# On va donc intégrer une matrice de masquage dans le processus. Cette matrice indique que pour le premier caractère de la séquence, on ne peux utiliser que ce caractère pour prédire (pas de contexte). Pour le second caractère, on peut utiliser le premier caractère et le second. Pour le troisième caractère, on peut utiliser le premier, le second et le troisième et ainsi de suite. Cette matrice est donc une matrice triangulaire inférieure. Cette matrice est normalisée par ligne (les lignes somment à 1).

# %%
T = 8

# first version of the contraints with matrix multiplication
# create a lower triangular matrix
weights0 = torch.tril(torch.ones(T,T))
# normalize each row
weights0 = weights0 / weights0.sum(1, keepdim=True) 
print (weights0)
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3333, 0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2500, 0.2500, 0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.0000, 0.0000, 0.0000],
#         [0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.0000, 0.0000],
#         [0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.0000],
#         [0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250]])

# %% [markdown]
# La couche [`softmax`](https://pytorch.org/docs/stable/generated/torch.nn.functional.softmax.html) est une autre manière de réaliser la normalisation :
#
# Question :
# > * Vérifier qu'on obtient bien la même matrice.

# %%
tril = torch.tril(torch.ones(T,T))
weights = torch.tril(torch.ones(T,T))
weights = weights.masked_fill(tril== 0, float('-inf'))
weights = nn.functional.softmax(weights, dim=-1)
print (weights)
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3333, 0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2500, 0.2500, 0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.0000, 0.0000, 0.0000],
#         [0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.0000, 0.0000],
#         [0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.0000],
#         [0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250]])

# %% [markdown]
# ### Implémentation
#
# Nous pouvons maintenant implémenter la couche d'attention :
#
# ![attention_formula](images/attention_formula.png)

# %% [markdown]
# Questions :
#
# > * Créer les couches key, query et value comme des couches linéaires de dimension `C` x `head_size`.
# > * Appliquer les couches à `x`.
# > * `weights = query x key` (transposer les deuxième et troisième dimensions de key pour pouvoir faire le produit).
# > * Appliquer le facteur de normalisation.
# > * Appliquer le masque triangulaire et la softmax à `weights`.
# > * Appliquer value à `x`.
# > * Le résultat `out` est la multiplication de `weights` par `value(x)`.

# %%
head_size = 16
B, T, C = 4, 8, 32
x = torch.randn(B, T, C)
## YOUR CODE HERE
# define the Key layer  
key = nn.Linear(C, head_size)
# define the Query layer
query = nn.Linear(C, head_size)
# define the Value layer
value =  nn.Linear(C, head_size)
# apply each layer to the input
k = key(x) # (B, T, head_size)
q = query(x) # (B, T, head_size)
v = value(x) # (B, T, head_size)
# compute the normalize product between Q and K
weights = q @ k.transpose(1,2) # (B, T, head_size) @ (B, 16, head_size) -> (B, T, T)
# apply the mask (lower triangular matrix)
weights = weights.masked_fill(tril== 0, float('-inf'))
# apply the softmax
weights = nn.functional.softmax(weights, dim=-1)
###
out  = weights @ value(x) # (B, T, head_size)

# print the result
weights[0]
out[0]
# Out:
# tensor([[-0.2479, -0.4348, -0.1208,  0.5206, -0.9599, -0.5751, -0.6087, -0.0501,
#          -0.4331,  0.0996, -0.4804, -0.1922, -0.1598,  0.6037, -0.6208, -0.2855],
#         [-0.1966, -0.3825, -0.1004,  0.5050, -0.8584, -0.5183, -0.6780, -0.0203,
#          -0.4332,  0.1194, -0.3861, -0.1605, -0.2389,  0.5365, -0.6176, -0.2577],
#         [ 0.0137, -0.4102,  0.0716,  0.3524, -0.3824, -0.3860, -0.6117,  0.1081,
#          -0.0479,  0.1973, -0.2281,  0.1818, -0.1623,  0.5015, -0.6658, -0.4018],
#         [-0.0925, -0.3808,  0.1935,  0.1364,  0.1774,  0.0178, -0.0379,  0.0466,
#           0.1985,  0.5216, -0.0509,  0.8721,  0.0150,  0.4923, -0.5390, -0.3993],
#         [-0.2957, -0.2376, -0.2019,  0.5678, -0.6855, -0.2214, -0.2731, -0.0979,
#          -0.3814, -0.2365, -0.1641,  0.0488, -0.1286,  0.5417, -0.5554, -0.0669],
#         [-0.4053, -0.0155, -0.3955,  0.7283, -0.4919,  0.1842,  0.3109, -0.1966,
#          -0.2704, -0.9979,  0.1763,  0.2581,  0.0682,  0.5777, -0.5024,  0.2291],
#         [-0.3240, -0.1158, -0.1410,  0.5354, -0.2769,  0.1254,  0.1144, -0.1233,
#          -0.2366, -0.3239,  0.1781,  0.3623, -0.1303,  0.5396, -0.3371, -0.0503],
#         [ 0.3940,  0.2507,  0.1789,  0.4679,  0.4944,  0.2536, -1.3762,  0.3421,
#          -0.5104,  0.3925,  0.8811,  0.3079, -1.2412, -0.2006, -0.3699,  0.0280]],
#        grad_fn=<SelectBackward0>)

# %% [markdown]
# Questions :
#
# > * Copier votre code dans `gpt_single_head.py` : la définition des couches dans le constructeur de la classe `Head` et les calculs dans la fonction `forward`.
# > * Faire un entrainement.
# > * Quelle loss en train et val obtenez vous ? Le texte vous parait-il meilleur ?

# %% [markdown]
# Train loss : 2.3423
#
# Val loss : 2.4739
#
# Le texte est beaucoup plus satisfaisant, on reconnait presque des mots. La ponctuation semble également correcte, on a des majuscules en début de phrases et des points à la fin.
#
#
#
#
# Texte généré :
#
# I O che.
# .
#   j'u le cha cer doralqu'acavis, sachaintarcorile reumait les, et de;
# Le er! sames daient chacéce ouoisey: ffaudeut,  le lai ge Uu lars'ute,
# Sansomdaint en;
# I Cen s'he Et d'ont, strêteursoun jauitosonerll'ascombr veu taivit fan cesceux;
# Quis jesu mass hants st mbre Pa lais su ou s meurource cai mitrevand'orure me maurspel qu'upret farbrsonus aplaries oriembetteursi t êmevanite bond'hous epranques s pral le Doile lant monnt;
#
#  E
#
# Jons les  vommac ple,
# Bol'au ton'es, von, lust, anciet a

# %% [markdown]
# ## Multi-head attention
#
# La *multi-head attention* est simplement le calcul en parallèle de plusieurs *single head attention*. Chacune des single head attention est concaténée pour créer la sortie de la multi-head attention. Dans la figure issue de l'article original, le nombre de *heads* dans le *multi-head* est `h`. Afin d'opérer des combinaisons pondérées sur la sortie de chacune des single head, une couche de calcul linéaire est ajoutée.
#
# ![multi head attention](images/multi_head_attention.png)
#
# Le code ci-dessous crée un module de multi-head attention.
# Questions :
# > * Dans le constructeur, créer une liste contenant `num_heads` module `Head` en utilisant la fonction [ModuleList](https://pytorch.org/docs/stable/generated/torch.nn.ModuleList.html) de pytorch.
# > * Dans la fonction `forward`, appliquer chaque single head à l'input et concaténer le résultat en utilisant la fonction [cat](https://pytorch.org/docs/stable/generated/torch.cat.html) de pytorch.

# %%
class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        ## YOUR CODE HERE
        ## list of num_heads modules of type Head
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        ###
        
    def forward(self, x):
        ## YOUR CODE HERE
        ## apply each head in self.heads to x and concat the results 
        out = torch.cat([h(x) for h in self.heads], dim=-1)

        return out

# %% [markdown]
# Questions :
# > * Copier le fichier `gpt_single_head.py` en `gpt_multi_head.py`.
# > * Ajouter le module MultiHeadAttention dans `gpt_multi_head.py`.
# > * En tête de fichier, ajouter un paramètre  `n_head = 4`.
# > * Dans le module BigramLanguageModel, remplacer le module Head par un module MultiHeadAttention avec les paramètres `num_heads = n_head` et `head_size = n_embd // n_head` pour garder le même nombre de paramètres.
# > Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.

# %% [markdown]
# 0.009989 M parameters
#
# Train loss : 2.1476
#
# Val loss : 2.1939
#
# Texte généré :
#
# Iis che.
# Hre,    O le mênertsoralqu'avail,
# S'acheur arcort enteux vieu.»
#
# L'é,    L'er! damex da ent chacépe ruonsey: font;
# Et
# Et noire ge Upérars tée,
# Sans maient en;
# Il»
# Et dée En d'ont, sur Saur vux jaux donger: des de à veux le fa far cesceux;
# QuiS'e,
# Commis, Cèrelst me,
# ...
# Noum,-ôtpengienspeuté trers du cain le,»
#         teursi tuêmevent, haubrembux en pour sourisants, Doir quen voux, blqu'êsursi les lots voin.
# Trots te et que,
# Con,    de aunieux

# %% [markdown]
# ## Ajout d'une couche de calcul FeedForward
#
#
# Après les couches d'attention qui collectent l'information dans la séquence, une couche de calcul est ajoutée pour combiner toutes les informations de la séquence. Cette couche est un simple Multi-Layer-Perceptron avec une couche cachée et une non linéarité de type [RELU](https://pytorch.org/docs/stable/generated/torch.nn.ReLU.html).
# ![multi feedfoward](images/multi_ff.png)

# %%
class FeedForward(nn.Module):
    """ a simple MLP with RELU """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, n_embd),
            nn.ReLU(),
        )

    def forward(self, x):
        return self.net(x)

# %% [markdown]
# Questions :
# > * Ajouter le module `FeedForward` dans votre fichier `gpt_multi_head.py`.
# > * Ajouter cette couche `FeedForward` après la *multi-head attention*.
# > * Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.

# %% [markdown]
# 0.011045 M parameters
#
# Train loss : 2.1069
#
# Val loss : 2.1455
#
# Texte généré :
#
# Otrit,
# In
# Oax;
# De m'ai Cen ont lus un que raiond;
# Feis sons, va nui des cromme un le qu'uné,
# L'ent garde, ma voi, vill, pes jue dest l'i an sans defsur
# Et sO-s ceursé noure à spchome l'anbrate croin tu où l'à cous cr'es sui lis alleur, le chotre de d'an voient d'anouce fla mon in ve less proil;
# Lu leiss.
# Caênomme
# L'ozaionfhosez fabît;
# Et srait fardreut et le l'une;
# Su, me un selle à et de téraple soniraces déste Ulur cet j'i, finfaîlez vort plavec e det voraux,
# Et ppore
# L'e  chartilà maicons da

# %% [markdown]
# ## Empiler les blocs
#
# Le réseau construit jusqu'à présent n'est en fait qu'un bloc du réseau final. Il est maintenant possible d'empiler les blocs de *multi-head attention* pour créer un réseau profond.
#
# ![multi feedfoward](images/multi_bloc.png)
#
#
# Le code suivant crée un bloc :

# %%
class Block(nn.Module):
    """ A single bloc of multi-head attention """

    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedForward(n_embd)

    def forward(self, x):
        x = self.sa(x)
        x = self.ffwd(x)
        return x

# %% [markdown]
# Questions :
# > * Ajouter le module `Block` dans `gpt_multi_head.py`.
# > * Modifier le code de `BigramLanguageModel` pour ajouter 3 `Block(n_embd, n_head=4)` avec un container [Sequential](https://pytorch.org/docs/stable/generated/torch.nn.Sequential.html) à la place de `MultiHeadAttention`et `FeedForward`.
# > * Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.

# %% [markdown]
# 0.019493 M parameters
#
# Train loss : 2.2031
#
# Val loss : 2.2435
#
# Texte généré :
#
# Dobers le porleuv!
# Queits lesale maials le rrous sim dais pour sierres et li!
# Aù dain
#        Ntés pun lur l'AâFovion, boulu,
# Et touge,
# Avamre ext la!
# Soux d'reul  la lit, dant et Te ves seurre qui glar;
# Fal viese dièt ut l'as Marce,
# L'evopûtelsarons en le tuu de vose pants!
#
# L'obletr lui se quez é lure voin, atru ta MéRavaîe;
# Tu pont l'a piy,
# ...
# Na dety reumboir etout qu'utécae
# Lan la paitartéran comroise mrus fae, mêt ait p Mamiri.

# %% [markdown]
# ## Amélioration de l'entraînement
#
# Si on veut continuer à augmenter la taille du réseau, il est nécessaire d'utiliser des couches permettant d'améliorer l'entraînement et ses capacités de généralisation (réduire le sur-apprentissage). Ces couches sont :
# - *skip connections* ou *residual connections*
# - les couches de normalisation
# - le dropout.
#
#
# ![multi feedfoward](images/multi_skip_norm.png)
#
#
# Questions :
# > * Dans le module Block, ajouter une skip connection en ajoutant l'input dans chaque connexion :
# ```
#         x = x + self.sa(self.ln1(x))
#         x = x + self.ffwd(self.ln2(x))
# ```
# > * Dans le module Block, ajouter 2 couches de [LayerNorm](https://pytorch.org/docs/stable/generated/torch.nn.LayerNorm.html) de taille `n_embd` avant la couche de `Multi-Head attention` et avant la `FeedForward`.
# > * Après la série de 3 blocs, ajouter une couche de LayerNorm de taille `n_embd`.
# > * Définir une variable `dropout = 0.2` en début de fichier et ajouter une couche de [Dropout](https://pytorch.org/docs/stable/generated/torch.nn.Dropout.html) :
# >    * Après la couche RELU dans FeedForward
# >    * Après la couche de MultiHead dans `MultiHeadAttention`
# >    * Après la softmax dans la single head attention `Head`.
# > * Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.

# %% [markdown]
# 0.019941 M parameters
#
# Train loss : 2.0638
#
# Val loss : 2.0422
#
# Texte généré :
#
# Si vingare méséla que les souts. de
# Pans l'étontila sumormaime eienchsenour.
# Où l'acar que sors la vess détes vour d'ul, des s'itses enue et fl'ine;
# Jes ves es re, êve, on, on des-muais pouTon a sords, ubret r'ilcre,.
# Le ses, re poivernil quu'émère qui de mêle le rous laps noit ibrendi du flus sombriEtand sois mare furiarièt enc d'oubes sobrir.
# Les fe inchis, chre voutant misez! estrané;
#
# Vol sa pavent vire l'et me surofête!
# Certénoidre, fantonge, lu fonitent!
# Dès l'aus cre du gonla pires le

# %% [markdown]
# ## Conclusion
#
# Les principaux éléments de GPT2 sont en place, il faut maintenant faire passer le modèle à l'échelle et l'entraîner sur une base de données beaucoup plus grande. Pour comparaison, les paramètres de [GPT2](https://huggingface.co/transformers/v2.11.0/model_doc/gpt2.html) sont :
#
# * `vocab_size = 50257` : GPT2 modélise des tokens (subwords) alors que nous modélisons des caractères. Pour nous, `vocab_size = 100`.
# * `n_positions = 1024` : la taille maximale du contexte. Pour nous, c'est `block_size = 8`.
# * `n_embd = 768`:  la dimension des embeddings. Pour nous c'est `n_embd = 32`.
# * `n_layer = 12`: le nombre de block. Pour nous c'est 3.
# * `n_head = 12`: le nombre de multi-head attention. Pour nous c'est 4.
#
# Au total, GPT2 est composé de 1,500 millions de paramètres et a été entrainé sur 8M de pages web, soit 40 Gb de texte.
#
#
# ```
# 10.816613 M parameters
# step 0: train loss 4.7847, val loss 4.7701
# step 4999: train loss 0.2683, val loss 2.1161
# time: 31m47.910s
#
# Le pêcheur où l'homme en peu de Carevante
# Sa conter des chosses qu'en ses yoitn!
#
# Ils sont là-hauts parler à leurs ténèbres
# A ceux qu'on rêve aux oiseaux des cheveux,
# Et celus qu'on tourna jamais sous le front;
# Ils se disent tu mêle aux univers.
# J'ai vu Jean vu France, potte; petits contempler,
# Et petié calme au milibre et versait,
# M'éblouissant, emportant, écoute, ingorancessible,
# On meurt s'efferayait.....--Pas cont âme parle en Apparia!
# ```
